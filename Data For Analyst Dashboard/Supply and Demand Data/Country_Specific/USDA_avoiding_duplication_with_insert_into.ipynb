# %% [markdown]
# 4236000	Oil, Sunflowerseed
#
# 2224000	Oilseed, Sunflowerseed
#
# 4239100	Oil, Rapeseed
#
# 2226000	Oilseed, Rapeseed
#
# 4232000	Oil, Soybean
#
# 2222000	Oilseed, Soybean
#
# 4243000	Oil, Palm
#
#
# 4235000	Oil, Olive
#
# 4242000	Oil, Coconut
#
#
#
#
# 4233000	Oil, Cottonseed
# 4244000	Oil, Palm Kernel
# 4234000	Oil, Peanut
# 4232001	Oil, Soybean (Local)

# %%
# from datetime import datetime, timedelta
# from sshtunnel import SSHTunnelForwarder
# import pandas as pd
# import pymysql
# import mysql.connector
# from requests.structures import CaseInsensitiveDict
# import requests

# # MySQL Database B SSH configuration
# b_ssh_host = '18.195.40.197'
# b_ssh_user = 'forge'
# b_ssh_port = 22
# b_ssh_private_key = '/Users/germankosenkov/.ssh/id_rsa'
# b_sql_hostname = 'gehrman.ccq0tjftm3pw.eu-central-1.rds.amazonaws.com'
# b_sql_username = 'gehrman'
# b_sql_password = 'ycEqAKjqFZH3sH'
# b_sql_database = 'vesper'
# b_sql_port = 3306

# value = 0

# years = [2019, 2020, 2021, 2022, 2023]

# # Connect to Database B and insert data
# with SSHTunnelForwarder(
#         (b_ssh_host, b_ssh_port),
#         ssh_username=b_ssh_user,
#         ssh_pkey=b_ssh_private_key,
#         remote_bind_address=(b_sql_hostname, b_sql_port)) as tunnel:
#     b_conn = pymysql.connect(
#         host='127.0.0.1',
#         user=b_sql_username,
#         passwd=b_sql_password,
#         db=b_sql_database,
#         port=tunnel.local_bind_port
#     )
#     b_cursor = b_conn.cursor()

#     for year in years:

#         url_list = [
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4236000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4239100&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4232000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4243000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4235000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4242000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4233000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4244000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4234000&marketYear={year}",
#             #f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4232001&marketYear={year}"

#         ]

#         for url in url_list:
#             headers = CaseInsensitiveDict()
#             headers["Accept"] = "application/json"
#             headers["API_KEY"] = "68F6B0D6-444E-43C0-A4E1-64CF5D3710B7"

#             resp = requests.get(url, headers=headers)
#             print(resp.status_code)

#             if resp.status_code == 200:
#                 data = resp.json()

#                 sql = sql = "INSERT IGNORE INTO USDA_SnD (CommodityCode, CommodityDescription, CountryCode, CountryName, MarketYear, CalendarYear, Month,  AttributeDescription, UnitId, UnitDescription, Value) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"

#                 for item in data:
#                     val = (
#                         item["CommodityCode"], item["CommodityDescription"], item["CountryCode"],
#                         item["CountryName"], item["MarketYear"], item["CalendarYear"], item["Month"],
#                         item["AttributeDescription"], item["UnitId"],
#                         item["UnitDescription"], item["Value"]
#                     )
#                 b_cursor.execute(sql, val)

#     b_conn.commit()

#     b_cursor.close()
#     b_conn.close()

# print(b_cursor.rowcount, "record(s) inserted.")

# %% [markdown]
# Oilseeds

# %%
# from datetime import datetime, timedelta
# from sshtunnel import SSHTunnelForwarder
# import pandas as pd
# import pymysql
# import mysql.connector
# from requests.structures import CaseInsensitiveDict
# import requests

# # MySQL Database B SSH configuration
# b_ssh_host = '18.195.40.197'
# b_ssh_user = 'forge'
# b_ssh_port = 22
# b_ssh_private_key = '/Users/germankosenkov/.ssh/id_rsa'
# b_sql_hostname = 'gehrman.ccq0tjftm3pw.eu-central-1.rds.amazonaws.com'
# b_sql_username = 'gehrman'
# b_sql_password = 'ycEqAKjqFZH3sH'
# b_sql_database = 'vesper'
# b_sql_port = 3306


# years = [2019, 2020, 2021, 2022, 2023]

# # Connect to Database B and insert data
# with SSHTunnelForwarder(
#         (b_ssh_host, b_ssh_port),
#         ssh_username=b_ssh_user,
#         ssh_pkey=b_ssh_private_key,
#         remote_bind_address=(b_sql_hostname, b_sql_port)) as tunnel:
#     b_conn = pymysql.connect(
#         host='127.0.0.1',
#         user=b_sql_username,
#         passwd=b_sql_password,
#         db=b_sql_database,
#         port=tunnel.local_bind_port
#     )
#     b_cursor = b_conn.cursor()

#     for year in years:
#         url_list = [
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=2231000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=2223000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=2232000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=2221000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=2226000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=2222000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=2224000&marketYear={year}"    
#         ]

#         for url in url_list:
#             headers = CaseInsensitiveDict()
#             headers["Accept"] = "application/json"
#             headers["API_KEY"] = "68F6B0D6-444E-43C0-A4E1-64CF5D3710B7"

#             resp = requests.get(url, headers=headers)
#             print(resp.status_code)

#             if resp.status_code == 200:
#                 data = resp.json()

#                 sql = "INSERT INTO USDA_SnD (CommodityCode, CommodityDescription, CountryCode, CountryName, MarketYear, CalendarYear, Month, AttributeDescription, UnitId, UnitDescription, Value) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"

#                 for item in data:
#                     val = (
#                         item["CommodityCode"], item["CommodityDescription"], item["CountryCode"],
#                         item["CountryName"], item["MarketYear"], item["CalendarYear"], item["Month"],
#                         item["AttributeDescription"], item["UnitId"],
#                         item["UnitDescription"], item["Value"]
#                     )
#                     b_cursor.execute(sql, val)

#     # Commit changes and close cursor and connection
#     b_conn.commit()
#     b_cursor.close()
#     b_conn.close()

# print(b_cursor.rowcount, "record(s) inserted.")

# %% [markdown]
# country code
#
# country_codes = [
#     "AC", "BF", "BB", "BD", "CU", "DO", "DR", "Y2", "GJ", "GP",
#     "HA", "JM", "MB", "NA", "RQ", "SC", "ST", "VC", "TD", "VO",
#     "BH", "CS", "ES", "GT", "HO", "NU", "PN", "CH", "HK", "JA",
#     "KN", "KS", "MC", "MG", "TW", "AU", "S8", "BE", "BU", "HR",
#     "CY", "EZ", "DA", "EN", "E2", "E3", "E4", "FI", "CZ", "FR",
#     "GC", "GM", "GE", "GR", "HU", "EI", "IT", "LG", "LH", "LU",
#     "MT", "NL", "PL", "PO", "RO", "LO", "SI", "SP", "SW", "AM",
#     "AJ", "BO", "GG", "KZ", "KG", "MD", "RS", "TI", "TX", "UP",
#     "UR", "UZ", "BA", "GZ", "IR", "IZ", "IS", "JO", "KU", "LE",
#     "MU", "QA", "SA", "SY", "TU", "TC", "YM", "YS", "YE", "AG",
#     "EG", "LY", "MO", "TS", "CA", "GL", "MX", "US", "ZZ", "AS",
#     "FJ", "FP", "GN", "NC", "NZ", "PP", "WS", "BP", "TN", "NH",
#     "AL", "BK", "FO", "YO", "GI", "IC", "KV", "MJ", "MK", "NO",
#     "RB", "SR", "SZ", "UK", "YU", "AR", "BL", "BR", "CI", "CO",
#     "EC", "FA", "FG", "GY", "PA", "PE", "NS", "UY", "VE", "AF",
#     "BG", "BT", "IN", "MV", "NP", "PK", "CE", "BX", "BM", "CB",
#     "ID", "LA", "MY", "RP", "SN", "TH", "VM", "AO", "DM", "BC",
#     "UV", "BY", "CV", "CM", "CT", "CD", "CN", "CF", "CG", "IV",
#     "DJ", "EK", "ER", "WZ", "ET", "FT", "GB", "GA", "GH", "GU",
#     "PU", "KE", "LT", "LI", "MA", "MI", "ML", "MR", "MP", "MZ",
#     "WA", "NG", "NI", "RE", "RW", "TP", "SG", "SE", "SL", "SO",
#     "SF", "OD", "SU", "TZ", "TO", "UG", "ZA", "RH"
# ]
#
# years = [2019, 2020, 2021, 2022, 2023]
#
# codes = [4236000, 2224000, 4239100, 2226000, 4232000, 2222000, 4243000, 4235000, 4242000, 4233000, 4244000, 4234000, 4232001, 2231000, 2223000 , 2232000 ,2221000,
# 2226000	, 2222000 , 2222001, 2224000 ]

# %%
# from datetime import datetime, timedelta
# from sshtunnel import SSHTunnelForwarder
# import pandas as pd
# import pymysql
# import mysql.connector
# from requests.structures import CaseInsensitiveDict
# import requests

# # MySQL Database B SSH configuration
# b_ssh_host = '18.195.40.197'
# b_ssh_user = 'forge'
# b_ssh_port = 22
# b_ssh_private_key = '/Users/germankosenkov/.ssh/id_rsa'
# b_sql_hostname = 'gehrman.ccq0tjftm3pw.eu-central-1.rds.amazonaws.com'
# b_sql_username = 'gehrman'
# b_sql_password = 'ycEqAKjqFZH3sH'
# b_sql_database = 'vesper'
# b_sql_port = 3306


# years = [2019, 2020, 2021, 2022, 2023]

# # Connect to Database B and insert data
# with SSHTunnelForwarder(
#         (b_ssh_host, b_ssh_port),
#         ssh_username=b_ssh_user,
#         ssh_pkey=b_ssh_private_key,
#         remote_bind_address=(b_sql_hostname, b_sql_port)) as tunnel:
#     b_conn = pymysql.connect(
#         host='127.0.0.1',
#         user=b_sql_username,
#         passwd=b_sql_password,
#         db=b_sql_database,
#         port=tunnel.local_bind_port
#     )
#     b_cursor = b_conn.cursor()

#     for year in years:
#         url_list = [
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4236000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4239100&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4232000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4243000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4235000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4242000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4233000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4244000&marketYear={year}",
#             f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4234000&marketYear={year}",
#             #f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetWorldCommodityDataByYear?commodityCode=4232001&marketYear={year}"

#         ]

#         for url in url_list:
#             headers = CaseInsensitiveDict()
#             headers["Accept"] = "application/json"
#             headers["API_KEY"] = "68F6B0D6-444E-43C0-A4E1-64CF5D3710B7"

#             resp = requests.get(url, headers=headers)
#             print(resp.status_code)

#             if resp.status_code == 200:
#                 data = resp.json()

#                 sql = "INSERT INTO USDA_SnD (CommodityCode, CommodityDescription, CountryCode, CountryName, MarketYear, CalendarYear, Month, AttributeDescription, UnitId, UnitDescription, Value) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"

#                 for item in data:
#                     val = (
#                         item["CommodityCode"], item["CommodityDescription"], item["CountryCode"],
#                         item["CountryName"], item["MarketYear"], item["CalendarYear"], item["Month"],
#                         item["AttributeDescription"], item["UnitId"],
#                         item["UnitDescription"], item["Value"]
#                     )
#                     b_cursor.execute(sql, val)

#     # Commit changes and close cursor and connection
#     b_conn.commit()
#     b_cursor.close()
#     b_conn.close()

# print(b_cursor.rowcount, "record(s) inserted.")

# %%
from datetime import datetime, timedelta
from sshtunnel import SSHTunnelForwarder
import pandas as pd
import pymysql
import mysql.connector
from requests.structures import CaseInsensitiveDict
import requests

# MySQL Database B SSH configuration
b_ssh_host = '18.195.40.197'
b_ssh_user = 'forge'
b_ssh_port = 22
b_ssh_private_key = '/Users/germankosenkov/.ssh/id_rsa'
b_sql_hostname = 'gehrman.ccq0tjftm3pw.eu-central-1.rds.amazonaws.com'
b_sql_username = 'gehrman'
b_sql_password = 'ycEqAKjqFZH3sH'
b_sql_database = 'vesper'
b_sql_port = 3306



country_codes = [
"ID", "MY"
]


years = [2019]

codes = [4236000], #2224000, 4239100, 2226000, 4232000, 2222000, 4243000, 4235000, 4242000, 4233000, 4244000, 4234000, 4232001, 2231000, 2223000 , 2232000 ,2221000,	
#2226000	, 2222000 , 2222001, 2224000 ]	

commodities = [{"country": country, "code": code, "year": year} for country in country_codes for year in years for code in codes]



# Connect to Database B and insert data
with SSHTunnelForwarder(
        (b_ssh_host, b_ssh_port),
        ssh_username=b_ssh_user,
        ssh_pkey=b_ssh_private_key,
        remote_bind_address=(b_sql_hostname, b_sql_port)) as tunnel:
    b_conn = pymysql.connect(
        host='127.0.0.1',
        user=b_sql_username,
        passwd=b_sql_password,
        db=b_sql_database,
        port=tunnel.local_bind_port
    )
    b_cursor = b_conn.cursor()
 

    for commodity in commodities:
        code = commodity["code"]
        year = commodity["year"]
        country = commodity["country"]
        
        url = f"https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetCommodityDataByYear?commodityCode={code}&marketYear={year}&countryCode={country}"

        headers = CaseInsensitiveDict()
        headers["Accept"] = "application/json"
        headers["API_KEY"] = "68F6B0D6-444E-43C0-A4E1-64CF5D3710B7"

        resp = requests.get(url, headers=headers)
        print(resp.status_code)

        if resp.status_code == 200:
            data = resp.json()
            df = pd.DataFrame(data)
            print(data)

            

            # sql = "INSERT IGNORE INTO USDA_SnD (CommodityCode, CommodityDescription, CountryCode, CountryName, MarketYear, CalendarYear, Month,  AttributeDescription, UnitId, UnitDescription, Value) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"

            # for item in data:
            #     val = (
            #         item["CommodityCode"], item["CommodityDescription"], item["CountryCode"],
            #         item["CountryName"], item["MarketYear"], item["CalendarYear"], item["Month"],
            #         item["AttributeDescription"], item["UnitId"],
            #         item["UnitDescription"], item["Value"]
            #     )
            #     b_cursor.execute(sql, val)

# Commit changes and close cursor and connection
b_conn.commit()
b_cursor.close()
b_conn.close()

print(b_cursor.rowcount, "record(s) inserted.")
# Out:
# 404
# 404
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /var/folders/qs/26crv4l161g4k3cvlckx2s5h0000gn/T/ipykernel_7209/3212424985.py in <module>
#      83
#      84 # Commit changes and close cursor and connection
# ---> 85 b_conn.commit()
#      86 b_cursor.close()
#      87 b_conn.close()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in commit(self)
#     470         """
#     471         self._execute_command(COMMAND.COM_QUERY, "COMMIT")
# --> 472         self._read_ok_packet()
#     473
#     474     def rollback(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in _read_ok_packet(self)
#     440
#     441     def _read_ok_packet(self):
# --> 442         pkt = self._read_packet()
#     443         if not pkt.is_ok_packet():
#     444             raise err.OperationalError(
#
# ...

# %%
from datetime import datetime, timedelta
from sshtunnel import SSHTunnelForwarder
import pandas as pd
import pymysql
import mysql.connector
from requests.structures import CaseInsensitiveDict
import requests


url = "https://apps.fas.usda.gov/PSDOnlineDataServices/api/CommodityData/GetCommodityDataByYear?commodityCode=2226000&marketYear=2024"

headers = CaseInsensitiveDict()
headers["Accept"] = "application/json"
headers["API_KEY"] = "68F6B0D6-444E-43C0-A4E1-64CF5D3710B7"

resp = requests.get(url, headers=headers)
print(resp.status_code)

pd.set_option('display.max_rows', None)


if resp.status_code == 200:
    data = resp.json()
    df = pd.DataFrame(data)
    print(df)
# Out:
# 200
#     CommodityCode            CommodityDescription CountryCode  \
# 0         2226000  Oilseed, Rapeseed                       AR
# 1         2226000  Oilseed, Rapeseed                       AR
# 2         2226000  Oilseed, Rapeseed                       AR
# 3         2226000  Oilseed, Rapeseed                       AR
# 4         2226000  Oilseed, Rapeseed                       AR
# 5         2226000  Oilseed, Rapeseed                       AR
# 6         2226000  Oilseed, Rapeseed                       AR
# 7         2226000  Oilseed, Rapeseed                       AR
# 8         2226000  Oilseed, Rapeseed                       AR
# 9         2226000  Oilseed, Rapeseed                       AR
# 10        2226000  Oilseed, Rapeseed                       AR
# 11        2226000  Oilseed, Rapeseed                       AR
# 12        2226000  Oilseed, Rapeseed                       AR
# 13        2226000  Oilseed, Rapeseed                       AR
# ...
